# %%
import RL
import numpy as np
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Creating grid world environment

# %%
grid_rows = 5
grid_cols = 8
num_actions = 8
living_rewards = .1
terminal_states = [0, 8, 16, 18, 21, 24, 26]
terminal_rewards = {0:-1, 8:1, 16:-1, 18:-1, 21:-1, 24:-1, 26:-1}

env = RL.GridWorldEnv(grid_rows, grid_cols, num_actions, terminal_states, 
                      terminal_rewards, prob_noise=.01, 
                      living_rewards=living_rewards, initial_state=33)

n = env.n
m = env.m
states = env.states
actions = env.actions

# %% [markdown]
# # Creating model free instance to run algorithms

# %%
# Created instance of class to run model free based algorithms.
model_free_rl = RL.ModelFreeRL(n=n, m=m, states=states, actions=actions, alpha=.6, alpha_decay=True,
                               alpha_decay_param=.01, gamma=.95, num_episodes=5000, 
                               epsilon=.1, horizon=100, epsilon_decay=True, 
                               epsilon_decay_param=.0001)

# %% [markdown]
# # Q-Learning

# %%
model_free_rl.q_learning(env)

display = RL.GridDisplay(model_free_rl, env)
display.show_values(title='Grid World: Q-Learning Values')
display.show_q_values(title='Grid World: Q-Learning Q-Values')

# %%
q_error = model_free_rl.test_optimal_q(env)
v_error = model_free_rl.test_optimal_v(env)
print v_error.max()
print q_error.max()
# Out:
# 11.706594505
# 27.3373259357

# %% [markdown]
# # Plotting episode returns and parameters across episodes

# %%
# Plotting the returns at each episode.
model_free_rl.scatter_epsiode_returns()

# Plotting the epsilon parameters at each episode.
model_free_rl.plot_epsilon_parameters()

# Plotting the step size parameter for a state.
model_free_rl.plot_alpha_parameters(s=33, a=0)

# %% [markdown]
# # Creating model based instance to run algorithms

# %%
# Created instance of class to run model based algorithms.
model_rl = RL.ModelBasedRL(max_eval=1000, gamma=.95)
mdp = RL.GridWorldMDP(grid_rows, grid_cols, num_actions, terminal_states, 
                      terminal_rewards, prob_noise=.01, 
                      living_rewards=living_rewards)

# %% [markdown]
# # Q-Value Iteration

# %%
model_rl.q_value_iteration(mdp)

display = RL.GridDisplay(model_rl, mdp)

display.show_q_values(title='Grid World: Q-Value Iteration')
display.show_values(title='Grid World: Q-Value Iteration')

# %%
q_error = model_rl.test_optimal_q(mdp)
v_error = model_rl.test_optimal_v(mdp)
print v_error.max()
print q_error.max()
# Out:
# 9.28907687978e-05
# 9.28907687978e-05

# %% [markdown]
# # Creating an agent with a prospect value function who is risk adverse in losses and risk neutral in gains

# %%
agent_neutral = RL.ProspectAgent(ref=0, c_minus=1, c_plus=1, rho_minus=1, rho_plus=1)
agent_risk_low = RL.ProspectAgent(ref=0, c_minus=4, c_plus=1, rho_minus=.5, rho_plus=.5)
agent_risk_mid = RL.ProspectAgent(ref=0, c_minus=8, c_plus=1, rho_minus=.5, rho_plus=.5)
agent_risk_high = RL.ProspectAgent(ref=0, c_minus=16, c_plus=1, rho_minus=.5, rho_plus=.5)

# %%
grid_rows = 5
grid_cols = 8
num_actions = 8
living_rewards = .1
terminal_states = [0, 8, 16, 18, 21, 24, 26]
terminal_rewards = {0:-1, 8:1, 16:-1, 18:-1, 21:-1, 24:-1, 26:-1}

env = RL.GridWorldEnv(grid_rows, grid_cols, num_actions, terminal_states, 
                      terminal_rewards, prob_noise=.05, 
                      living_rewards=living_rewards, initial_state=33)

n = env.n
m = env.m
states = env.states
actions = env.actions

# %%
# Created instance of class to run model free based algorithms.
model_free_risk_rl = RL.ModelFreeRiskRL(n=n, m=m, states=states, actions=actions, 
                                       alpha=.4, alpha_decay=True,
                                       alpha_decay_param=.01, gamma=.95, num_episodes=5000, 
                                       epsilon=.2, horizon=100, epsilon_decay=True, 
                                       epsilon_decay_param=.0001)

# %% [markdown]
# # Risk Sensitive Q-Learning - Mapping of temporal differences

# %%
# epsilon = .3, alpha=.6
long_ = RL.ProspectAgent(ref=0, c_minus=2, c_plus=1, rho_minus=.5, rho_plus=.5)
# epsilon =.2, alpha=.4
mid = RL.ProspectAgent(ref=0, c_minus=1.6, c_plus=1, rho_minus=.5, rho_plus=.5)

# epsilon =.2, alpha=4
hide = RL.ProspectAgent(ref=0, c_minus=2.5, c_plus=1, rho_minus=.5, rho_plus=.5)
agent.plot_value_function(title='Prospect Agent')

# %%
model_free_risk_rl.risk_q_learning(env, long_)

display = RL.GridDisplay(model_free_risk_rl, env)
display.show_values(title='Grid World: Risk Sensitive Q-Learning Values')
display.show_q_values(title='Grid World: Risk Sensitive Q-Learning Q-Values')

# %%
model_free_risk_rl.risk_q_learning(env, agent_neutral)

display = RL.GridDisplay(model_free_risk_rl, env)
display.show_values(title='Grid World: Risk Sensitive Q-Learning Values')
# display.show_q_values(title='Grid World: Risk Sensitive Q-Learning Q-Values')

# %%
model_free_risk_rl.risk_q_learning(env, agent_risk_low)

display = RL.GridDisplay(model_free_risk_rl, env)
display.show_values(title='Grid World: Risk Sensitive Q-Learning Values')
# display.show_q_values(title='Grid World: Risk Sensitive Q-Learning Q-Values')

# %%
model_free_risk_rl.risk_q_learning(env, agent_risk_mid)

display = RL.GridDisplay(model_free_risk_rl, env)
display.show_values(title='Grid World: Risk Sensitive Q-Learning Values')
# display.show_q_values(title='Grid World: Risk Sensitive Q-Learning Q-Values')

# %%
# Plotting the returns at each episode.
model_free_rl.plot_epsiode_returns()

# Plotting the epsilon parameters at each episode.
model_free_rl.plot_epsilon_parameters()

# Plotting the step size parameter for a state.
model_free_rl.plot_alpha_parameters(s=2)

# %%
agent = RL.ProspectAgent(c_minus=1, c_plus=1, rho_minus=1, rho_plus=1, ref=0)
agent.plot_value_function(title='Prospect Agent')

agent = RL.ProspectAgent(c_minus=2, c_plus=1, rho_minus=.5, rho_plus=.5, ref=0)
agent.plot_value_function(title='Prospect Agent')

agent = RL.ProspectAgent(c_minus=4, c_plus=1, rho_minus=.5, rho_plus=.5, ref=0)
agent.plot_value_function(title='Prospect Agent')

agent = RL.ProspectAgent(c_minus=8, c_plus=1, rho_minus=.5, rho_plus=.5, ref=0)
agent.plot_value_function(title='Prospect Agent')

# %%
agent = RL.LogAgent(rho_minus=.5, rho_plus=.5, ref=1)
agent.plot_value_function(title='Log Agent')

# %%
agent = RL.EntropicAgent(lamb=-.2, ref=1)
agent.plot_value_function(title='Entropic Agent')
